# %%
import pandas as pd 
from matplotlib import pyplot as plt

# %%
file = open('../data/lichess_db_standard_rated_2013-01.csv', 'r')

amount = 0

for line in file.readlines():
    print(line.count(','))
    amount += line.count(',')
print(amount)
file.close()


# df = pd.read_csv('../data/game_data.csv')
# display(df.head())
# Out:
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# ...
